# %% [markdown]
# <a href="https://colab.research.google.com/github/Parfowhat/Plus-W_UOK-Data-Science-/blob/main/Class 2 Assignment/Q3/Treasure%20Island%20Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instructions
# 1. print("Welcome to Treasure Island.")
# 2. print("Your mission is to find the treasure.")
# 3. choice1 = input() #'You\'re at a cross road. Where do you want to go? Type "left" or "right" \n'
# 4. choice2 = input() #'You\'ve come to a lake. There is an island in the middle of the lake. Type "wait" to wait for a boat. Type "swim" to swim across. \n'
# 5. Complete this treasure game by using the below flow chart ![image.png](data:image/png;base64,...)

# %%
print("Welcome to Treasure Island.")
print("Your mission is to find the treasure.")

choice1 = input('You\'re at a crossroad. Where do you want to go? Type "left" or "right" \n')

if choice1.lower() == 'left':
    choice2 = input('You\'ve come to a lake. There is an island in the middle of the lake. Type "wait" to wait for a boat. Type "swim" to swim across. \n')

    if choice2.lower() == 'wait':
        choice3 = input('You\'ve come inside a castle. There are multiple doors inside the castle. Type "Red" to go inside the Red color door. Type "Yellow" to go inside the Yellow color door. Type "Blue" to go inside the Blue color door. \n')

        if choice3.lower() == 'red':
            print("You are burned by fire. Game over!")
        elif choice3.lower() == 'yellow':
            print("Congratulations! You successfully hunted the treasure. You win!")
        elif choice3.lower() == 'blue':
            print("You are eaten by beasts. Game over!")
        else:
            print("Game over! You chose the wrong door.")

    else:
        print("You are attacked by trout. Game over!")

else:
    print("You fell into a hole. Game over!")
# Out:
# Welcome to Treasure Island.
# Your mission is to find the treasure.
# You're at a crossroad. Where do you want to go? Type "left" or "right"
# left
# You've come to a lake. There is an island in the middle of the lake. Type "wait" to wait for a boat. Type "swim" to swim across.
# wait
# You've come inside a castle. There are multiple doors inside the castle. Type "Red" to go inside the Red color door. Type "Yellow" to go inside the Yellow color door. Type "Blue" to go inside the Blue color door.
# red
# You are burned by fire. Game over!
